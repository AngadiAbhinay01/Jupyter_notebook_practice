# %%
#creation of singly linked list

class Node:
    def __init__(self,value = None):
        self.value = value
        self.next = None

class sLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
singlyLinkedList = sLinkedList()
node1 = Node(1)
node2 = Node(2)

singlyLinkedList.head = node1
singlyLinkedList.head.next = node2
singlyLinkedList.tail = node2

# %%
#insertion of singly linked list 

class Node:
    def __init__(self,value = None):
        self.value = value
        self.next = None
class sLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
            
#insert in linked list

    def insert(self,value,location):
        newNode = Node(value)
        if self.head is None:
            self.head = newNode
            self.tail = newNode
        else:
            if location == 0:                     #inserting element at beginning
                newNode.next = self.head
                self.head = newNode
            elif location == 1:                   #insering element at end
                newNode.next = None
                self.tail.next = newNode
                self.tail = newNode
            else:
                tempNode = self.head
                index = 0
                while index < location-1:
                    tempNode = tempNode.next
                    index = index+1
            
                    nextNode = tempNode.next
                    tempNode.next = newNode
                    newNode.next = nextNode        
        
        
singlyLinkedList = sLinkedList()
singlyLinkedList.insert(1,1)
singlyLinkedList.insert(2,1)
singlyLinkedList.insert(3,1)
singlyLinkedList.insert(4,1)
singlyLinkedList.insert('a',0)
singlyLinkedList.insert('b',5)

print([node.value for node in singlyLinkedList])
# Out:
# ['a', 1, 'b', 3, 4]

# %%
#traversing singly linked list

class Node:
    def __init__(self,value = None):
        self.value = value
        self.next = None
class sLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
    def insert(self,value,location):
        newNode = Node(value)
        if self.head is None:
            self.head = newNode
            self.tail = newNode
        else:
            if location == 0:                     #inserting element at beginning
                newNode.next = self.head
                self.head = newNode
            elif location == 1:                   #insering element at end
                newNode.next = None
                self.tail.next = newNode
                self.tail = newNode
            else:                                 #inserting element at middlel
                tempNode = self.head
                index = 0
                while index < location-1:
                    tempNode = tempNode.next
                    index = index+1
            
                    nextNode = tempNode.next
                    tempNode.next = newNode
                    newNode.next = nextNode                    
    
    def traverse(self):
        if self.head is None:
            print("linked list doesn't exist")
        else:
            node = self.head
            while node is not None:
                print(node.value)
                node = node.next

singlyLinkedList = sLinkedList()
singlyLinkedList.insert(1,1)
singlyLinkedList.insert(2,1)
singlyLinkedList.insert(3,1)
singlyLinkedList.insert(4,1)
singlyLinkedList.insert('a',0)
singlyLinkedList.insert('b',5)

print([node.value for node in singlyLinkedList]) 

singlyLinkedList.traverse()
# Out:
# ['a', 1, 'b', 3, 4]
# a
# 1
# b
# 3
# 4

# %%
#search in linked list
class Node:
    def __init__(self,value = None):
        self.value = value
        self.next = None
class sLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
    def insert(self,value,location):
        newNode = Node(value)
        if self.head is None:
            self.head = newNode
            self.tail = newNode
        else:
            if location == 0:                     #inserting element at beginning
                newNode.next = self.head
                self.head = newNode
            elif location == 1:                   #insering element at end
                newNode.next = None
                self.tail.next = newNode
                self.tail = newNode
            else:                                 #inserting element at middlel
                tempNode = self.head
                index = 0
                while index < location-1:
                    tempNode = tempNode.next
                    index = index+1
            
                    nextNode = tempNode.next
                    tempNode.next = newNode
                    newNode.next = nextNode 
    
    def search(self,nodeValue):
        if self.head is None:
            return "linked list doesn't exit"
        else:
            node = self.head
            while node is not None:
                if node.value == nodeValue:
                    return node.value
                node = node.next
            return "nodeValue doesn't exist"
        
singlyLinkedList = sLinkedList()
singlyLinkedList.insert(1,1)
singlyLinkedList.insert(2,1)
singlyLinkedList.insert(3,1)
singlyLinkedList.insert(4,1)
singlyLinkedList.insert('a',0)
singlyLinkedList.insert('b',5)

print([node.value for node in singlyLinkedList]) 
print(singlyLinkedList.search(40))
# Out:
# ['a', 1, 'b', 3, 4]
# nodeValue doesn't exist

# %%
#deletion of node from singly linked list

class Node:
    def __init__(self,value = None):
        self.value = value
        self.next = None
class sLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
            
#insert in linked list

    def insert(self,value,location):
        newNode = Node(value)
        if self.head is None:
            self.head = newNode
            self.tail = newNode
        else:
            if location == 0:                     #inserting element at beginning
                newNode.next = self.head
                self.head = newNode
            elif location == 1:                   #insering element at end
                newNode.next = None
                self.tail.next = newNode
                self.tail = newNode
            else:
                tempNode = self.head
                index = 0
                while index < location-1:
                    tempNode = tempNode.next
                    index = index+1
            
                    nextNode = tempNode.next
                    tempNode.next = newNode
                    newNode.next = nextNode        
        

    def deleteNode(self,location):
        if self.head is None:
            print("SLL is doesn't exist")
        else:
            if location == 0:
                if self.head == self.tail:
                    self.head = None
                    self.tail = None
                else:
                    self.head = self.head.next
            elif location == 1:
                if self.head == self.tail:
                    self.head = None
                    self.tail = None
                else:
                    node = self.head
                    while node is not None:
                        if node.next == self.tail:
                            break
                        node = node.next
                    node.next = None
                    self.tail = node
            else:
                tempNode = self.head
                index = 0
                while index < location-1:
                    tempNode = tempNode.next
                    index += 1
                nextNode = tempNode.next
                tempNode.next = nextNode.next
        
singlyLinkedList = sLinkedList()
singlyLinkedList.insert(1,1)
singlyLinkedList.insert(2,1)
singlyLinkedList.insert(3,1)
singlyLinkedList.insert(4,1)
singlyLinkedList.insert('a',0)
singlyLinkedList.insert('b',5)

print([node.value for node in singlyLinkedList]) 

print(singlyLinkedList.deleteNode(5))

print([node.value for node in singlyLinkedList])
# Out:
# ['a', 1, 'b', 3, 4]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-0c54d00002be> in <module>
#      84 print([node.value for node in singlyLinkedList])
#      85
# ---> 86 print(singlyLinkedList.deleteNode(5))
#      87
#      88 print([node.value for node in singlyLinkedList])
#
# <ipython-input-9-0c54d00002be> in deleteNode(self, location)
#      72                     index += 1
#      73                 nextNode = tempNode.next
# ---> 74                 tempNode.next = nextNode.next
#      75
#      76 singlyLinkedList = sLinkedList()
#
# AttributeError: 'NoneType' object has no attribute 'next'

# %%
#delete entire linked list

class Node:
    def __init__(self,value = None):
        self.value = value
        self.next = None
class sLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    def __iter__(self):
        node = self.head
        while node:
            yield node
            node = node.next
            
#insert in linked list

    def insert(self,value,location):
        newNode = Node(value)
        if self.head is None:
            self.head = newNode
            self.tail = newNode
        else:
            if location == 0:                     #inserting element at beginning
                newNode.next = self.head
                self.head = newNode
            elif location == 1:                   #insering element at end
                newNode.next = None
                self.tail.next = newNode
                self.tail = newNode
            else:
                tempNode = self.head
                index = 0
                while index < location-1:
                    tempNode = tempNode.next
                    index = index+1
            
                    nextNode = tempNode.next
                    tempNode.next = newNode
                    newNode.next = nextNode        
    def deleteEntireSLL(self):
        if self.head is None:
            print("linked list doesn't exits")
        else:
            self.head = None
            self.tail = None
            
        
singlyLinkedList = sLinkedList()
singlyLinkedList.insert(1,1)
singlyLinkedList.insert(2,1)
singlyLinkedList.insert(3,1)
singlyLinkedList.insert(4,1)
singlyLinkedList.insert('a',0)
singlyLinkedList.insert('b',5)

print([node.value for node in singlyLinkedList]) 

print(singlyLinkedList.deleteEntireSLL())

print([node.value for node in singlyLinkedList])
# Out:
# ['a', 1, 'b', 3, 4]
# None
# []
